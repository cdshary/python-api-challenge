# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

print(api_key)
# Out:
# 716d516826209c3448c90ff3f3511f3e

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" #Fahrenheit

# %%
# Build partial query URL
query_url = url + "appid=" + api_key + "&units=" + units + "&q="

# List for holding the latitude and temperature

city_list = []
cloudiness_data = []
country_data = []
date_data = []
humidity_data = []
lat_data = []
lon_data = []
max_temp_data = []
wind_speed_data = []

count = 0

for city in cities:
    count+= 1
    
    try:
        print("----------------------")
        print("Now logging city # " + str(count))
        print(query_url +  city)
        weather_response = requests.get(query_url +  city).json()
        # extract key value pairs from dict into lists
        
        city_list.append(weather_response['name'])
        lat_data.append(weather_response['coord']['lat'])
        lon_data.append(weather_response['coord']['lon'])
        max_temp_data.append(weather_response['main']['temp_max'])
        humidity_data.append(weather_response['main']['humidity'])
        cloudiness_data.append(weather_response['clouds']['all'])
        wind_speed_data.append(weather_response['wind']['speed'])
       # break
        # wait
        time.sleep(3)
    except:
        print('city not found.')
# Out:
# ----------------------
# Now logging city # 1
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=qaanaaq
# ----------------------
# Now logging city # 2
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=amapa
# ----------------------
# Now logging city # 3
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=severo-kurilsk
# ----------------------
# Now logging city # 4
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sardarpur
# ----------------------
# Now logging city # 5
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tyukhtet
# ----------------------
# Now logging city # 6
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=vaini
# ----------------------
# Now logging city # 7
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saint-philippe
# ----------------------
# Now logging city # 8
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=isla mujeres
# ----------------------
# Now logging city # 9
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=yellowknife
# ----------------------
# Now logging city # 10
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=synya
# ----------------------
# Now logging city # 11
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=agva
# city not found.
# ----------------------
# Now logging city # 12
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=barrow
# ----------------------
# Now logging city # 13
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=cape town
# ----------------------
# Now logging city # 14
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=hobyo
# ----------------------
# Now logging city # 15
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=rikitea
# ----------------------
# Now logging city # 16
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=pacific grove
# ----------------------
# Now logging city # 17
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=carballo
# ----------------------
# Now logging city # 18
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=codrington
# ----------------------
# Now logging city # 19
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=korla
# city not found.
# ----------------------
# Now logging city # 20
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nchelenge
# ----------------------
# Now logging city # 21
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bluff
# ----------------------
# Now logging city # 22
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kapaa
# ----------------------
# Now logging city # 23
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mataura
# ----------------------
# Now logging city # 24
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=gat
# ----------------------
# Now logging city # 25
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kurmanayevka
# ----------------------
# Now logging city # 26
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=hobart
# ----------------------
# Now logging city # 27
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ostrovnoy
# ----------------------
# Now logging city # 28
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=avarua
# ----------------------
# Now logging city # 29
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=esperance
# ----------------------
# Now logging city # 30
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=arraial do cabo
# ----------------------
# Now logging city # 31
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kuche
# city not found.
# ----------------------
# Now logging city # 32
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mahebourg
# ----------------------
# Now logging city # 33
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=alta floresta
# ----------------------
# Now logging city # 34
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=attawapiskat
# city not found.
# ----------------------
# Now logging city # 35
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=zyryanka
# ----------------------
# Now logging city # 36
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bengkulu
# city not found.
# ----------------------
# Now logging city # 37
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bethel
# ----------------------
# Now logging city # 38
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=camacha
# ----------------------
# Now logging city # 39
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=norman wells
# ----------------------
# Now logging city # 40
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bredasdorp
# ----------------------
# Now logging city # 41
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=jamestown
# ----------------------
# Now logging city # 42
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=alice
# ----------------------
# Now logging city # 43
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saint george
# ----------------------
# Now logging city # 44
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=malibu
# ----------------------
# Now logging city # 45
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=cidreira
# ----------------------
# Now logging city # 46
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=port blair
# ----------------------
# Now logging city # 47
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=lerwick
# ----------------------
# Now logging city # 48
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=plettenberg bay
# ----------------------
# Now logging city # 49
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=manzhouli
# ----------------------
# Now logging city # 50
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=provideniya
# ----------------------
# Now logging city # 51
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=albany
# ----------------------
# Now logging city # 52
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=roald
# ----------------------
# Now logging city # 53
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=carutapera
# ----------------------
# Now logging city # 54
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=punta arenas
# ----------------------
# Now logging city # 55
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=seoul
# ----------------------
# Now logging city # 56
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=illoqqortoormiut
# city not found.
# ----------------------
# Now logging city # 57
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ushuaia
# ----------------------
# Now logging city # 58
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tottori
# ----------------------
# Now logging city # 59
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=necochea
# ----------------------
# Now logging city # 60
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=busselton
# ----------------------
# Now logging city # 61
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=valdivia
# ----------------------
# Now logging city # 62
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=koulamoutou
# ----------------------
# Now logging city # 63
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=barentsburg
# city not found.
# ----------------------
# Now logging city # 64
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=castro
# ----------------------
# Now logging city # 65
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=boras
# ----------------------
# Now logging city # 66
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=soloneshnoye
# ----------------------
# Now logging city # 67
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=moose factory
# ----------------------
# Now logging city # 68
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=port lincoln
# ----------------------
# Now logging city # 69
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=peniche
# ----------------------
# Now logging city # 70
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=monatele
# city not found.
# ----------------------
# Now logging city # 71
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=new norfolk
# ----------------------
# Now logging city # 72
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=longlac
# city not found.
# ----------------------
# Now logging city # 73
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=carnarvon
# ----------------------
# Now logging city # 74
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saskylakh
# ----------------------
# Now logging city # 75
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tsihombe
# city not found.
# ----------------------
# Now logging city # 76
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=hermanus
# ----------------------
# Now logging city # 77
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kamenskoye
# city not found.
# ----------------------
# Now logging city # 78
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=pangnirtung
# ----------------------
# Now logging city # 79
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=klaksvik
# ----------------------
# Now logging city # 80
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=juneau
# ----------------------
# Now logging city # 81
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mbini
# ----------------------
# Now logging city # 82
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=boa vista
# ----------------------
# Now logging city # 83
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=laguna
# ----------------------
# Now logging city # 84
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=chimbote
# ----------------------
# Now logging city # 85
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=husavik
# ----------------------
# Now logging city # 86
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=naron
# ----------------------
# Now logging city # 87
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=binga
# ----------------------
# Now logging city # 88
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=salalah
# ----------------------
# Now logging city # 89
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=faya
# ----------------------
# Now logging city # 90
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=srednekolymsk
# ----------------------
# Now logging city # 91
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=farmington
# ----------------------
# Now logging city # 92
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sept-iles
# ----------------------
# Now logging city # 93
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=san patricio
# ----------------------
# Now logging city # 94
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=airai
# ----------------------
# Now logging city # 95
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=guerrero negro
# ----------------------
# Now logging city # 96
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=luanda
# ----------------------
# Now logging city # 97
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=avera
# ----------------------
# Now logging city # 98
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=belmonte
# ----------------------
# Now logging city # 99
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=joshimath
# ----------------------
# Now logging city # 100
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kalakamati
# ----------------------
# Now logging city # 101
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mao
# ----------------------
# Now logging city # 102
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ondjiva
# ----------------------
# Now logging city # 103
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=adwa
# ----------------------
# Now logging city # 104
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=conceicao do araguaia
# ----------------------
# Now logging city # 105
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=lorengau
# ----------------------
# Now logging city # 106
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bambous virieux
# ----------------------
# Now logging city # 107
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=san andres
# ----------------------
# Now logging city # 108
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=narsaq
# ----------------------
# Now logging city # 109
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nome
# ----------------------
# Now logging city # 110
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=belushya guba
# city not found.
# ----------------------
# Now logging city # 111
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=goderich
# ----------------------
# Now logging city # 112
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=berlevag
# ----------------------
# Now logging city # 113
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mar del plata
# ----------------------
# Now logging city # 114
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=namibe
# ----------------------
# Now logging city # 115
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=victor harbor
# ----------------------
# Now logging city # 116
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=atuona
# ----------------------
# Now logging city # 117
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=puerto ayora
# ----------------------
# Now logging city # 118
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=amderma
# city not found.
# ----------------------
# Now logging city # 119
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bathsheba
# ----------------------
# Now logging city # 120
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sitka
# ----------------------
# Now logging city # 121
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=georgetown
# ----------------------
# Now logging city # 122
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ilulissat
# ----------------------
# Now logging city # 123
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=collierville
# ----------------------
# Now logging city # 124
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kismayo
# city not found.
# ----------------------
# Now logging city # 125
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dikson
# ----------------------
# Now logging city # 126
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=telemaco borba
# ----------------------
# Now logging city # 127
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=cherskiy
# ----------------------
# Now logging city # 128
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=padang
# ----------------------
# Now logging city # 129
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=cabo san lucas
# ----------------------
# Now logging city # 130
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nizhneangarsk
# ----------------------
# Now logging city # 131
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=chuy
# ----------------------
# Now logging city # 132
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=jalu
# ----------------------
# Now logging city # 133
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=thompson
# ----------------------
# Now logging city # 134
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sentyabrskiy
# city not found.
# ----------------------
# Now logging city # 135
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dhidhdhoo
# ----------------------
# Now logging city # 136
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=outjo
# ----------------------
# Now logging city # 137
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=aklavik
# ----------------------
# Now logging city # 138
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sarankhola
# ----------------------
# Now logging city # 139
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=rio gallegos
# ----------------------
# Now logging city # 140
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=east london
# ----------------------
# Now logging city # 141
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kuah
# city not found.
# ----------------------
# Now logging city # 142
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=takhtamygda
# ----------------------
# Now logging city # 143
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kahului
# ----------------------
# Now logging city # 144
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bhattiprolu
# ----------------------
# Now logging city # 145
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=barcelona
# ----------------------
# Now logging city # 146
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=oranjemund
# ----------------------
# Now logging city # 147
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=umm lajj
# ----------------------
# Now logging city # 148
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=krasnoselkup
# city not found.
# ----------------------
# Now logging city # 149
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=itoman
# ----------------------
# Now logging city # 150
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=noumea
# ----------------------
# Now logging city # 151
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ixtapa
# ----------------------
# Now logging city # 152
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dunedin
# ----------------------
# Now logging city # 153
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=galchino
# city not found.
# ----------------------
# Now logging city # 154
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saint anthony
# ----------------------
# Now logging city # 155
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sao filipe
# ----------------------
# Now logging city # 156
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=port alfred
# ----------------------
# Now logging city # 157
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=samusu
# city not found.
# ----------------------
# Now logging city # 158
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=butaritari
# ----------------------
# Now logging city # 159
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=terenos
# ----------------------
# Now logging city # 160
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=upernavik
# ----------------------
# Now logging city # 161
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=houston
# ----------------------
# Now logging city # 162
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=acajutla
# ----------------------
# Now logging city # 163
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=maceio
# ----------------------
# Now logging city # 164
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bubaque
# ----------------------
# Now logging city # 165
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=fairbanks
# ----------------------
# Now logging city # 166
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mayo
# ----------------------
# Now logging city # 167
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tual
# ----------------------
# Now logging city # 168
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mys shmidta
# city not found.
# ----------------------
# Now logging city # 169
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=san cristobal
# ----------------------
# Now logging city # 170
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=burgeo
# ----------------------
# Now logging city # 171
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=papillion
# ----------------------
# Now logging city # 172
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=abu samrah
# ----------------------
# Now logging city # 173
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=jiroft
# city not found.
# ----------------------
# Now logging city # 174
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nampula
# ----------------------
# Now logging city # 175
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=isangel
# ----------------------
# Now logging city # 176
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=taolanaro
# city not found.
# ----------------------
# Now logging city # 177
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sulangan
# ----------------------
# Now logging city # 178
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=marabba
# ----------------------
# Now logging city # 179
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=empangeni
# ----------------------
# Now logging city # 180
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=adrar
# ----------------------
# Now logging city # 181
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=alofi
# ----------------------
# Now logging city # 182
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=chingirlau
# ----------------------
# Now logging city # 183
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=touros
# ----------------------
# Now logging city # 184
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=odweyne
# city not found.
# ----------------------
# Now logging city # 185
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kaitangata
# ----------------------
# Now logging city # 186
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=valdez
# ----------------------
# Now logging city # 187
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=broken hill
# ----------------------
# Now logging city # 188
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bargal
# city not found.
# ----------------------
# Now logging city # 189
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=daru
# ----------------------
# Now logging city # 190
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kununurra
# ----------------------
# Now logging city # 191
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=souillac
# ----------------------
# Now logging city # 192
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=san juan
# ----------------------
# Now logging city # 193
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=gulshat
# city not found.
# ----------------------
# Now logging city # 194
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=cap malheureux
# ----------------------
# Now logging city # 195
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=hualmay
# ----------------------
# Now logging city # 196
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=radece
# ----------------------
# Now logging city # 197
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=isabela
# ----------------------
# Now logging city # 198
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bilma
# ----------------------
# Now logging city # 199
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=el alto
# ----------------------
# Now logging city # 200
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tiksi
# ----------------------
# Now logging city # 201
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=huarmey
# ----------------------
# Now logging city # 202
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=macusani
# ----------------------
# Now logging city # 203
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=pochutla
# ----------------------
# Now logging city # 204
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=hilo
# ----------------------
# Now logging city # 205
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=basco
# ----------------------
# Now logging city # 206
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saldanha
# ----------------------
# Now logging city # 207
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=rawson
# ----------------------
# Now logging city # 208
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=torbay
# ----------------------
# Now logging city # 209
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=port elizabeth
# ----------------------
# Now logging city # 210
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=prince rupert
# ----------------------
# Now logging city # 211
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=broome
# ----------------------
# Now logging city # 212
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kamenka
# ----------------------
# Now logging city # 213
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=palu
# ----------------------
# Now logging city # 214
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=menongue
# ----------------------
# Now logging city # 215
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kushiro
# ----------------------
# Now logging city # 216
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=jiangyou
# ----------------------
# Now logging city # 217
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kloulklubed
# ----------------------
# Now logging city # 218
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nizhneyansk
# city not found.
# ----------------------
# Now logging city # 219
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=hervey bay
# ----------------------
# Now logging city # 220
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sabzevar
# ----------------------
# Now logging city # 221
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kenai
# ----------------------
# Now logging city # 222
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=port-cartier
# ----------------------
# Now logging city # 223
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=victoria
# ----------------------
# Now logging city # 224
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=the valley
# ----------------------
# Now logging city # 225
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=yen bai
# ----------------------
# Now logging city # 226
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=taoudenni
# ----------------------
# Now logging city # 227
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=poum
# ----------------------
# Now logging city # 228
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=abu dhabi
# ----------------------
# Now logging city # 229
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kiunga
# ----------------------
# Now logging city # 230
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=santa rosa
# ----------------------
# Now logging city # 231
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=muroto
# ----------------------
# Now logging city # 232
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=novaya lyada
# ----------------------
# Now logging city # 233
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=takoradi
# ----------------------
# Now logging city # 234
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=aberdeen
# ----------------------
# Now logging city # 235
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sakakah
# city not found.
# ----------------------
# Now logging city # 236
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=udachnyy
# ----------------------
# Now logging city # 237
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=pyu
# ----------------------
# Now logging city # 238
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=alice springs
# ----------------------
# Now logging city # 239
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=boyolangu
# ----------------------
# Now logging city # 240
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=acapulco
# ----------------------
# Now logging city # 241
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=leshan
# ----------------------
# Now logging city # 242
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=karaul
# city not found.
# ----------------------
# Now logging city # 243
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saint-augustin
# ----------------------
# Now logging city # 244
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=flin flon
# ----------------------
# Now logging city # 245
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mana
# ----------------------
# Now logging city # 246
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=qaqortoq
# ----------------------
# Now logging city # 247
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=lavrentiya
# ----------------------
# Now logging city # 248
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ondangwa
# ----------------------
# Now logging city # 249
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=englewood
# ----------------------
# Now logging city # 250
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nguru
# ----------------------
# Now logging city # 251
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tura
# ----------------------
# Now logging city # 252
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kadirli
# ----------------------
# Now logging city # 253
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=vaitupu
# city not found.
# ----------------------
# Now logging city # 254
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=lebu
# ----------------------
# Now logging city # 255
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tumannyy
# city not found.
# ----------------------
# Now logging city # 256
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=atar
# ----------------------
# Now logging city # 257
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=yumen
# ----------------------
# Now logging city # 258
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=urucara
# ----------------------
# Now logging city # 259
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=xique-xique
# ----------------------
# Now logging city # 260
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kargasok
# ----------------------
# Now logging city # 261
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=severnyy
# city not found.
# ----------------------
# Now logging city # 262
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dingle
# ----------------------
# Now logging city # 263
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=pindiga
# ----------------------
# Now logging city # 264
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bulgan
# ----------------------
# Now logging city # 265
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=peleduy
# ----------------------
# Now logging city # 266
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=umm bab
# ----------------------
# Now logging city # 267
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ribeira grande
# ----------------------
# Now logging city # 268
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dauphin
# ----------------------
# Now logging city # 269
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=malko tarnovo
# ----------------------
# Now logging city # 270
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kavaratti
# ----------------------
# Now logging city # 271
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=komsomolskiy
# ----------------------
# Now logging city # 272
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ambilobe
# ----------------------
# Now logging city # 273
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bouca
# ----------------------
# Now logging city # 274
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=shreveport
# ----------------------
# Now logging city # 275
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=katobu
# ----------------------
# Now logging city # 276
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=senador jose porfirio
# ----------------------
# Now logging city # 277
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=khatanga
# ----------------------
# Now logging city # 278
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mehamn
# ----------------------
# Now logging city # 279
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=beringovskiy
# ----------------------
# Now logging city # 280
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=longyearbyen
# ----------------------
# Now logging city # 281
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=egvekinot
# ----------------------
# Now logging city # 282
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sorvag
# city not found.
# ----------------------
# Now logging city # 283
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=zalari
# ----------------------
# Now logging city # 284
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bontang
# ----------------------
# Now logging city # 285
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ulaanbaatar
# ----------------------
# Now logging city # 286
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=katsuura
# ----------------------
# Now logging city # 287
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=deniliquin
# ----------------------
# Now logging city # 288
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sorland
# ----------------------
# Now logging city # 289
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=surgut
# ----------------------
# Now logging city # 290
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=masumbwe
# ----------------------
# Now logging city # 291
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bernalillo
# ----------------------
# Now logging city # 292
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ryotsu
# ----------------------
# Now logging city # 293
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=college
# ----------------------
# Now logging city # 294
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nikolskoye
# ----------------------
# Now logging city # 295
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=altamira
# ----------------------
# Now logging city # 296
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=chastoozerye
# city not found.
# ----------------------
# Now logging city # 297
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tonstad
# ----------------------
# Now logging city # 298
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=grand gaube
# ----------------------
# Now logging city # 299
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=launceston
# ----------------------
# Now logging city # 300
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=tutoia
# ----------------------
# Now logging city # 301
# ...
# Now logging city # 523
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sug-aksy
# city not found.
# ----------------------
# Now logging city # 524
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=espinosa
# ----------------------
# Now logging city # 525
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kidal
# ----------------------
# Now logging city # 526
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=omsukchan
# ----------------------
# Now logging city # 527
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=diffa
# ----------------------
# Now logging city # 528
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=puerto baquerizo moreno
# ----------------------
# Now logging city # 529
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=torrington
# ----------------------
# Now logging city # 530
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=morondava
# ----------------------
# Now logging city # 531
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dalmatovo
# ----------------------
# Now logging city # 532
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ancona
# ----------------------
# Now logging city # 533
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saint-pierre
# ----------------------
# Now logging city # 534
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sola
# ----------------------
# Now logging city # 535
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=aksha
# ----------------------
# Now logging city # 536
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=turukhansk
# ----------------------
# Now logging city # 537
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=caravelas
# ----------------------
# Now logging city # 538
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=jumla
# ----------------------
# Now logging city # 539
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=svetlyy
# city not found.
# ----------------------
# Now logging city # 540
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=san juan de los morros
# ----------------------
# Now logging city # 541
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ouegoa
# ----------------------
# Now logging city # 542
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=puerto madryn
# ----------------------
# Now logging city # 543
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=yining
# ----------------------
# Now logging city # 544
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=vardo
# ----------------------
# Now logging city # 545
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=beyneu
# ----------------------
# Now logging city # 546
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dekar
# ----------------------
# Now logging city # 547
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=coos bay
# ----------------------
# Now logging city # 548
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=iguape
# ----------------------
# Now logging city # 549
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ksenyevka
# city not found.
# ----------------------
# Now logging city # 550
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bend
# ----------------------
# Now logging city # 551
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=jimenez
# ----------------------
# Now logging city # 552
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=aleksandrov gay
# ----------------------
# Now logging city # 553
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kosh-agach
# ----------------------
# Now logging city # 554
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=vao
# ----------------------
# Now logging city # 555
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kazalinsk
# city not found.
# ----------------------
# Now logging city # 556
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nanortalik
# ----------------------
# Now logging city # 557
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=vestmannaeyjar
# ----------------------
# Now logging city # 558
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=opelousas
# ----------------------
# Now logging city # 559
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=walvis bay
# ----------------------
# Now logging city # 560
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sattahip
# ----------------------
# Now logging city # 561
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bandarbeyla
# ----------------------
# Now logging city # 562
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=maltahohe
# ----------------------
# Now logging city # 563
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=inhambane
# ----------------------
# Now logging city # 564
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=masvingo
# ----------------------
# Now logging city # 565
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=raudeberg
# ----------------------
# Now logging city # 566
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=gushikawa
# ----------------------
# Now logging city # 567
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=verkh-suetka
# ----------------------
# Now logging city # 568
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=bousso
# city not found.
# ----------------------
# Now logging city # 569
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mogadishu
# ----------------------
# Now logging city # 570
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=ribeira brava
# ----------------------
# Now logging city # 571
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=djibo
# ----------------------
# Now logging city # 572
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=boende
# ----------------------
# Now logging city # 573
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sur
# ----------------------
# Now logging city # 574
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=havre-saint-pierre
# ----------------------
# Now logging city # 575
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saint-francois
# ----------------------
# Now logging city # 576
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nouadhibou
# ----------------------
# Now logging city # 577
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=altoona
# ----------------------
# Now logging city # 578
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kharp
# ----------------------
# Now logging city # 579
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=taua
# ----------------------
# Now logging city # 580
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=cockburn harbour
# city not found.
# ----------------------
# Now logging city # 581
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kaniama
# ----------------------
# Now logging city # 582
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=qobustan
# ----------------------
# Now logging city # 583
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dudinka
# ----------------------
# Now logging city # 584
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=invermere
# ----------------------
# Now logging city # 585
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=dongying
# ----------------------
# Now logging city # 586
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=phangnga
# ----------------------
# Now logging city # 587
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=sao raimundo nonato
# city not found.
# ----------------------
# Now logging city # 588
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kundiawa
# ----------------------
# Now logging city # 589
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=umzimvubu
# city not found.
# ----------------------
# Now logging city # 590
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kruisfontein
# ----------------------
# Now logging city # 591
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nabire
# ----------------------
# Now logging city # 592
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nguiu
# city not found.
# ----------------------
# Now logging city # 593
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nelson bay
# ----------------------
# Now logging city # 594
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=hofn
# ----------------------
# Now logging city # 595
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=saiha
# ----------------------
# Now logging city # 596
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=khandyga
# ----------------------
# Now logging city # 597
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=el sauzal
# ----------------------
# Now logging city # 598
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mezozombor
# ----------------------
# Now logging city # 599
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kaihua
# ----------------------
# Now logging city # 600
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=burnie
# ----------------------
# Now logging city # 601
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=norsup
# ----------------------
# Now logging city # 602
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=antakya
# ----------------------
# Now logging city # 603
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=zhigansk
# ----------------------
# Now logging city # 604
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=nemuro
# ----------------------
# Now logging city # 605
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=port-gentil
# ----------------------
# Now logging city # 606
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=mount gambier
# ----------------------
# Now logging city # 607
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=joao alfredo
# ----------------------
# Now logging city # 608
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=malanville
# ----------------------
# Now logging city # 609
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=conde
# ----------------------
# Now logging city # 610
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=koslan
# ----------------------
# Now logging city # 611
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=port macquarie
# ----------------------
# Now logging city # 612
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=west wendover
# ----------------------
# Now logging city # 613
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=antofagasta
# ----------------------
# Now logging city # 614
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=baykit
# ----------------------
# Now logging city # 615
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=chenzhou
# ----------------------
# Now logging city # 616
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=marcona
# city not found.
# ----------------------
# Now logging city # 617
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=rurrenabaque
# ----------------------
# Now logging city # 618
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=rocha
# ----------------------
# Now logging city # 619
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kpalime
# ----------------------
# Now logging city # 620
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=axim
# ----------------------
# Now logging city # 621
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=kallithea
# ----------------------
# Now logging city # 622
# http://api.openweathermap.org/data/2.5/weather?appid=716d516826209c3448c90ff3f3511f3e&units=imperial&q=yulara

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_datas = {'cities':city_list,
            'latitude': lat_data,
            'longitute': lon_data,
            'temp_max': max_temp_data,
            'humidity': humidity_data,
            'Cloudiness': cloudiness_data,
            'WindSpeed': wind_speed_data}



city_df = pd.DataFrame(city_datas)

# %%
 

city_csv = city_df.to_csv("city_datas.csv", index = False, header = True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_df['latitude'], city_df['temp_max'], color='blue', edgecolor='black', alpha=0.8)
plt.xlabel("Latitude", fontsize=10)
plt.ylabel("Maximum Temperatures (F)", fontsize=10)
plt.title("Latitude vs. Temperature", fontweight='bold', fontsize=13)

plt.savefig("temp_max.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_df['latitude'], city_df['humidity'], color='blue', edgecolor='lightgrey', alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title('Latitude vs. Humidity', fontweight='bold', fontsize=13)

plt.savefig("Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df['latitude'], city_df['Cloudiness'], color='black', edgecolor='grey', alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title('Latitude vs. Cloudiness', fontweight='bold', fontsize=13)

plt.savefig("Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df['latitude'], city_df['WindSpeed'], color='paleturquoise', edgecolor='pink', alpha=0.8)
plt.xlabel("Latitude")
plt.ylabel("WindSpeed (mph)")
plt.title('Latitude vs. WindSpeed', fontweight='bold', fontsize=13)

plt.savefig("WindSpeed.png")
